# %% [markdown]
# ## 三、日期的范围、频率以及移动

# %%
Image(filename="py35_picture\Date_Range.png")

# %%
print(ts)
print()
print(ts.resample('D').mean())
# Out:
# 2011-01-02   -0.916669
# 2011-01-05   -0.296275
# 2011-01-07   -0.052871
# 2011-01-08   -1.125371
# 2011-01-10    0.510460
# 2011-01-12    0.473304
# dtype: float64
#
# 2011-01-02   -0.916669
# 2011-01-03         NaN
# 2011-01-04         NaN
# 2011-01-05   -0.296275
# 2011-01-06         NaN
# 2011-01-07   -0.052871
# 2011-01-08   -1.125371
# 2011-01-09         NaN
# 2011-01-10    0.510460
# 2011-01-11         NaN
# 2011-01-12    0.473304
# Freq: D, dtype: float64

# %% [markdown]
# ### 1 生成日期范围

# %%
index = pd.date_range('4/1/2012', '6/1/2012') # 默认按天计算时间点
print(index)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
print(pd.date_range(start = '4/1/2012',periods = 20)) # 时间起始点，及一段长度
print()
print(pd.date_range(end = '6/1/2012',periods = 20))
print()
print(pd.date_range('6/1/2010','12/1/2000',freq = 'BM')) # bussiness end of month
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20'],
#               dtype='datetime64[ns]', freq='D')
#
# DatetimeIndex(['2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')
#
# DatetimeIndex([], dtype='datetime64[ns]', freq='BM')

# %%
print(pd.date_range('5/2/2012 12:56:31',periods = 5)) # 默认会保留起始和结束时间戳的时间信息
print()
print(pd.date_range('5/2/2012 12:56:31',periods = 5, normalize = True)) # 规范化到午夜的时间戳
# Out:
# DatetimeIndex(['2012-05-02 12:56:31', '2012-05-03 12:56:31',
#                '2012-05-04 12:56:31', '2012-05-05 12:56:31',
#                '2012-05-06 12:56:31'],
#               dtype='datetime64[ns]', freq='D')
#
# DatetimeIndex(['2012-05-02', '2012-05-03', '2012-05-04', '2012-05-05',
#                '2012-05-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ### 2 频率和日期偏移量

# %%
Image(filename="py35_picture\Freq date.png")

# %%
from pandas.tseries.offsets import Hour,Minute
hour = Hour()
print(hour)
print()
four_hours = Hour(4) # 传入整数即可定义偏移量的倍数
print(four_hours)
# Out:
# <Hour>
#
# <4 * Hours>

# %%
pd.date_range('1/1/2000','1/3/2000 23:59',freq = '4h')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
Hour(2) + Minute(30) # 大部分偏移量对象都可以通过加法进行连接
# Out:
# <150 * Minutes>

# %%
pd.date_range('1/1/2000',periods = 10, freq = '1h30min')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[ns]', freq='90T')

# %%
Image(filename="py35_picture\Base Frequency.png")

# %%
Image(filename="py35_picture\Base Frequency 2.png")

# %% [markdown]
# ### 3 WOM日期
# * Week of Month
# * 获得诸如“每月第三个星期五”之类的日期

# %%
rng = pd.date_range('1/1/2012','9/1/2012',frqe = 'WOM-3FRI')
list(rng)
# Out:
# [Timestamp('2012-01-01 00:00:00', offset='D'),
#  Timestamp('2012-01-02 00:00:00', offset='D'),
#  Timestamp('2012-01-03 00:00:00', offset='D'),
#  Timestamp('2012-01-04 00:00:00', offset='D'),
#  Timestamp('2012-01-05 00:00:00', offset='D'),
#  Timestamp('2012-01-06 00:00:00', offset='D'),
#  Timestamp('2012-01-07 00:00:00', offset='D'),
#  Timestamp('2012-01-08 00:00:00', offset='D'),
#  Timestamp('2012-01-09 00:00:00', offset='D'),
#  Timestamp('2012-01-10 00:00:00', offset='D'),
#  Timestamp('2012-01-11 00:00:00', offset='D'),
#  Timestamp('2012-01-12 00:00:00', offset='D'),
#  Timestamp('2012-01-13 00:00:00', offset='D'),
#  Timestamp('2012-01-14 00:00:00', offset='D'),
#  Timestamp('2012-01-15 00:00:00', offset='D'),
#  Timestamp('2012-01-16 00:00:00', offset='D'),
#  Timestamp('2012-01-17 00:00:00', offset='D'),
#  Timestamp('2012-01-18 00:00:00', offset='D'),
#  Timestamp('2012-01-19 00:00:00', offset='D'),
#  Timestamp('2012-01-20 00:00:00', offset='D'),
#  Timestamp('2012-01-21 00:00:00', offset='D'),
#  Timestamp('2012-01-22 00:00:00', offset='D'),
#  Timestamp('2012-01-23 00:00:00', offset='D'),
#  Timestamp('2012-01-24 00:00:00', offset='D'),
#  Timestamp('2012-01-25 00:00:00', offset='D'),
#  Timestamp('2012-01-26 00:00:00', offset='D'),
#  Timestamp('2012-01-27 00:00:00', offset='D'),
#  Timestamp('2012-01-28 00:00:00', offset='D'),
#  Timestamp('2012-01-29 00:00:00', offset='D'),
#  Timestamp('2012-01-30 00:00:00', offset='D'),
#  Timestamp('2012-01-31 00:00:00', offset='D'),
#  Timestamp('2012-02-01 00:00:00', offset='D'),
#  Timestamp('2012-02-02 00:00:00', offset='D'),
#  Timestamp('2012-02-03 00:00:00', offset='D'),
#  Timestamp('2012-02-04 00:00:00', offset='D'),
#  Timestamp('2012-02-05 00:00:00', offset='D'),
#  Timestamp('2012-02-06 00:00:00', offset='D'),
#  Timestamp('2012-02-07 00:00:00', offset='D'),
#  Timestamp('2012-02-08 00:00:00', offset='D'),
#  Timestamp('2012-02-09 00:00:00', offset='D'),
#  Timestamp('2012-02-10 00:00:00', offset='D'),
#  Timestamp('2012-02-11 00:00:00', offset='D'),
#  Timestamp('2012-02-12 00:00:00', offset='D'),
#  Timestamp('2012-02-13 00:00:00', offset='D'),
#  Timestamp('2012-02-14 00:00:00', offset='D'),
#  Timestamp('2012-02-15 00:00:00', offset='D'),
#  Timestamp('2012-02-16 00:00:00', offset='D'),
#  Timestamp('2012-02-17 00:00:00', offset='D'),
#  Timestamp('2012-02-18 00:00:00', offset='D'),
#  Timestamp('2012-02-19 00:00:00', offset='D'),
#  Timestamp('2012-02-20 00:00:00', offset='D'),
#  Timestamp('2012-02-21 00:00:00', offset='D'),
#  Timestamp('2012-02-22 00:00:00', offset='D'),
#  Timestamp('2012-02-23 00:00:00', offset='D'),
#  Timestamp('2012-02-24 00:00:00', offset='D'),
#  Timestamp('2012-02-25 00:00:00', offset='D'),
#  Timestamp('2012-02-26 00:00:00', offset='D'),
#  Timestamp('2012-02-27 00:00:00', offset='D'),
#  Timestamp('2012-02-28 00:00:00', offset='D'),
#  Timestamp('2012-02-29 00:00:00', offset='D'),
#  Timestamp('2012-03-01 00:00:00', offset='D'),
#  Timestamp('2012-03-02 00:00:00', offset='D'),
#  Timestamp('2012-03-03 00:00:00', offset='D'),
#  Timestamp('2012-03-04 00:00:00', offset='D'),
#  Timestamp('2012-03-05 00:00:00', offset='D'),
#  Timestamp('2012-03-06 00:00:00', offset='D'),
#  Timestamp('2012-03-07 00:00:00', offset='D'),
#  Timestamp('2012-03-08 00:00:00', offset='D'),
#  Timestamp('2012-03-09 00:00:00', offset='D'),
#  Timestamp('2012-03-10 00:00:00', offset='D'),
#  Timestamp('2012-03-11 00:00:00', offset='D'),
#  Timestamp('2012-03-12 00:00:00', offset='D'),
#  Timestamp('2012-03-13 00:00:00', offset='D'),
#  Timestamp('2012-03-14 00:00:00', offset='D'),
#  Timestamp('2012-03-15 00:00:00', offset='D'),
#  Timestamp('2012-03-16 00:00:00', offset='D'),
#  Timestamp('2012-03-17 00:00:00', offset='D'),
#  Timestamp('2012-03-18 00:00:00', offset='D'),
#  Timestamp('2012-03-19 00:00:00', offset='D'),
#  Timestamp('2012-03-20 00:00:00', offset='D'),
#  Timestamp('2012-03-21 00:00:00', offset='D'),
#  Timestamp('2012-03-22 00:00:00', offset='D'),
#  Timestamp('2012-03-23 00:00:00', offset='D'),
#  Timestamp('2012-03-24 00:00:00', offset='D'),
#  Timestamp('2012-03-25 00:00:00', offset='D'),
#  Timestamp('2012-03-26 00:00:00', offset='D'),
#  Timestamp('2012-03-27 00:00:00', offset='D'),
#  Timestamp('2012-03-28 00:00:00', offset='D'),
#  Timestamp('2012-03-29 00:00:00', offset='D'),
#  Timestamp('2012-03-30 00:00:00', offset='D'),
#  Timestamp('2012-03-31 00:00:00', offset='D'),
#  Timestamp('2012-04-01 00:00:00', offset='D'),
#  Timestamp('2012-04-02 00:00:00', offset='D'),
#  Timestamp('2012-04-03 00:00:00', offset='D'),
#  Timestamp('2012-04-04 00:00:00', offset='D'),
#  Timestamp('2012-04-05 00:00:00', offset='D'),
#  Timestamp('2012-04-06 00:00:00', offset='D'),
#  Timestamp('2012-04-07 00:00:00', offset='D'),
#  Timestamp('2012-04-08 00:00:00', offset='D'),
#  Timestamp('2012-04-09 00:00:00', offset='D'),
#  Timestamp('2012-04-10 00:00:00', offset='D'),
#  Timestamp('2012-04-11 00:00:00', offset='D'),
#  Timestamp('2012-04-12 00:00:00', offset='D'),
#  Timestamp('2012-04-13 00:00:00', offset='D'),
#  Timestamp('2012-04-14 00:00:00', offset='D'),
#  Timestamp('2012-04-15 00:00:00', offset='D'),
#  Timestamp('2012-04-16 00:00:00', offset='D'),
#  Timestamp('2012-04-17 00:00:00', offset='D'),
#  Timestamp('2012-04-18 00:00:00', offset='D'),
#  Timestamp('2012-04-19 00:00:00', offset='D'),
#  Timestamp('2012-04-20 00:00:00', offset='D'),
#  Timestamp('2012-04-21 00:00:00', offset='D'),
#  Timestamp('2012-04-22 00:00:00', offset='D'),
#  Timestamp('2012-04-23 00:00:00', offset='D'),
#  Timestamp('2012-04-24 00:00:00', offset='D'),
#  Timestamp('2012-04-25 00:00:00', offset='D'),
#  Timestamp('2012-04-26 00:00:00', offset='D'),
#  Timestamp('2012-04-27 00:00:00', offset='D'),
#  Timestamp('2012-04-28 00:00:00', offset='D'),
#  Timestamp('2012-04-29 00:00:00', offset='D'),
#  Timestamp('2012-04-30 00:00:00', offset='D'),
#  Timestamp('2012-05-01 00:00:00', offset='D'),
#  Timestamp('2012-05-02 00:00:00', offset='D'),
#  Timestamp('2012-05-03 00:00:00', offset='D'),
#  Timestamp('2012-05-04 00:00:00', offset='D'),
#  Timestamp('2012-05-05 00:00:00', offset='D'),
#  Timestamp('2012-05-06 00:00:00', offset='D'),
#  Timestamp('2012-05-07 00:00:00', offset='D'),
#  Timestamp('2012-05-08 00:00:00', offset='D'),
#  Timestamp('2012-05-09 00:00:00', offset='D'),
#  Timestamp('2012-05-10 00:00:00', offset='D'),
#  Timestamp('2012-05-11 00:00:00', offset='D'),
#  Timestamp('2012-05-12 00:00:00', offset='D'),
#  Timestamp('2012-05-13 00:00:00', offset='D'),
#  Timestamp('2012-05-14 00:00:00', offset='D'),
#  Timestamp('2012-05-15 00:00:00', offset='D'),
#  Timestamp('2012-05-16 00:00:00', offset='D'),
#  Timestamp('2012-05-17 00:00:00', offset='D'),
#  Timestamp('2012-05-18 00:00:00', offset='D'),
#  Timestamp('2012-05-19 00:00:00', offset='D'),
#  Timestamp('2012-05-20 00:00:00', offset='D'),
#  Timestamp('2012-05-21 00:00:00', offset='D'),
#  Timestamp('2012-05-22 00:00:00', offset='D'),
#  Timestamp('2012-05-23 00:00:00', offset='D'),
#  Timestamp('2012-05-24 00:00:00', offset='D'),
#  Timestamp('2012-05-25 00:00:00', offset='D'),
#  Timestamp('2012-05-26 00:00:00', offset='D'),
#  Timestamp('2012-05-27 00:00:00', offset='D'),
#  Timestamp('2012-05-28 00:00:00', offset='D'),
#  Timestamp('2012-05-29 00:00:00', offset='D'),
#  Timestamp('2012-05-30 00:00:00', offset='D'),
#  Timestamp('2012-05-31 00:00:00', offset='D'),
#  Timestamp('2012-06-01 00:00:00', offset='D'),
#  Timestamp('2012-06-02 00:00:00', offset='D'),
#  Timestamp('2012-06-03 00:00:00', offset='D'),
#  Timestamp('2012-06-04 00:00:00', offset='D'),
#  Timestamp('2012-06-05 00:00:00', offset='D'),
#  Timestamp('2012-06-06 00:00:00', offset='D'),
#  Timestamp('2012-06-07 00:00:00', offset='D'),
#  Timestamp('2012-06-08 00:00:00', offset='D'),
#  Timestamp('2012-06-09 00:00:00', offset='D'),
#  Timestamp('2012-06-10 00:00:00', offset='D'),
#  Timestamp('2012-06-11 00:00:00', offset='D'),
#  Timestamp('2012-06-12 00:00:00', offset='D'),
#  Timestamp('2012-06-13 00:00:00', offset='D'),
#  Timestamp('2012-06-14 00:00:00', offset='D'),
#  Timestamp('2012-06-15 00:00:00', offset='D'),
#  Timestamp('2012-06-16 00:00:00', offset='D'),
#  Timestamp('2012-06-17 00:00:00', offset='D'),
#  Timestamp('2012-06-18 00:00:00', offset='D'),
#  Timestamp('2012-06-19 00:00:00', offset='D'),
#  Timestamp('2012-06-20 00:00:00', offset='D'),
#  Timestamp('2012-06-21 00:00:00', offset='D'),
#  Timestamp('2012-06-22 00:00:00', offset='D'),
#  Timestamp('2012-06-23 00:00:00', offset='D'),
#  Timestamp('2012-06-24 00:00:00', offset='D'),
#  Timestamp('2012-06-25 00:00:00', offset='D'),
#  Timestamp('2012-06-26 00:00:00', offset='D'),
#  Timestamp('2012-06-27 00:00:00', offset='D'),
#  Timestamp('2012-06-28 00:00:00', offset='D'),
#  Timestamp('2012-06-29 00:00:00', offset='D'),
#  Timestamp('2012-06-30 00:00:00', offset='D'),
#  Timestamp('2012-07-01 00:00:00', offset='D'),
#  Timestamp('2012-07-02 00:00:00', offset='D'),
#  Timestamp('2012-07-03 00:00:00', offset='D'),
#  Timestamp('2012-07-04 00:00:00', offset='D'),
#  Timestamp('2012-07-05 00:00:00', offset='D'),
#  Timestamp('2012-07-06 00:00:00', offset='D'),
#  Timestamp('2012-07-07 00:00:00', offset='D'),
#  Timestamp('2012-07-08 00:00:00', offset='D'),
#  Timestamp('2012-07-09 00:00:00', offset='D'),
#  Timestamp('2012-07-10 00:00:00', offset='D'),
#  Timestamp('2012-07-11 00:00:00', offset='D'),
#  Timestamp('2012-07-12 00:00:00', offset='D'),
#  Timestamp('2012-07-13 00:00:00', offset='D'),
#  Timestamp('2012-07-14 00:00:00', offset='D'),
#  Timestamp('2012-07-15 00:00:00', offset='D'),
#  Timestamp('2012-07-16 00:00:00', offset='D'),
#  Timestamp('2012-07-17 00:00:00', offset='D'),
#  Timestamp('2012-07-18 00:00:00', offset='D'),
#  Timestamp('2012-07-19 00:00:00', offset='D'),
#  Timestamp('2012-07-20 00:00:00', offset='D'),
#  Timestamp('2012-07-21 00:00:00', offset='D'),
#  Timestamp('2012-07-22 00:00:00', offset='D'),
#  Timestamp('2012-07-23 00:00:00', offset='D'),
#  Timestamp('2012-07-24 00:00:00', offset='D'),
#  Timestamp('2012-07-25 00:00:00', offset='D'),
#  Timestamp('2012-07-26 00:00:00', offset='D'),
#  Timestamp('2012-07-27 00:00:00', offset='D'),
#  Timestamp('2012-07-28 00:00:00', offset='D'),
#  Timestamp('2012-07-29 00:00:00', offset='D'),
#  Timestamp('2012-07-30 00:00:00', offset='D'),
#  Timestamp('2012-07-31 00:00:00', offset='D'),
#  Timestamp('2012-08-01 00:00:00', offset='D'),
#  Timestamp('2012-08-02 00:00:00', offset='D'),
#  Timestamp('2012-08-03 00:00:00', offset='D'),
#  Timestamp('2012-08-04 00:00:00', offset='D'),
#  Timestamp('2012-08-05 00:00:00', offset='D'),
#  Timestamp('2012-08-06 00:00:00', offset='D'),
#  Timestamp('2012-08-07 00:00:00', offset='D'),
#  Timestamp('2012-08-08 00:00:00', offset='D'),
#  Timestamp('2012-08-09 00:00:00', offset='D'),
#  Timestamp('2012-08-10 00:00:00', offset='D'),
#  Timestamp('2012-08-11 00:00:00', offset='D'),
#  Timestamp('2012-08-12 00:00:00', offset='D'),
#  Timestamp('2012-08-13 00:00:00', offset='D'),
#  Timestamp('2012-08-14 00:00:00', offset='D'),
#  Timestamp('2012-08-15 00:00:00', offset='D'),
#  Timestamp('2012-08-16 00:00:00', offset='D'),
#  Timestamp('2012-08-17 00:00:00', offset='D'),
#  Timestamp('2012-08-18 00:00:00', offset='D'),
#  Timestamp('2012-08-19 00:00:00', offset='D'),
#  Timestamp('2012-08-20 00:00:00', offset='D'),
#  Timestamp('2012-08-21 00:00:00', offset='D'),
#  Timestamp('2012-08-22 00:00:00', offset='D'),
#  Timestamp('2012-08-23 00:00:00', offset='D'),
#  Timestamp('2012-08-24 00:00:00', offset='D'),
#  Timestamp('2012-08-25 00:00:00', offset='D'),
#  Timestamp('2012-08-26 00:00:00', offset='D'),
#  Timestamp('2012-08-27 00:00:00', offset='D'),
#  Timestamp('2012-08-28 00:00:00', offset='D'),
#  Timestamp('2012-08-29 00:00:00', offset='D'),
#  Timestamp('2012-08-30 00:00:00', offset='D'),
#  Timestamp('2012-08-31 00:00:00', offset='D'),
#  Timestamp('2012-09-01 00:00:00', offset='D')]

# %% [markdown]
# ### 4 移动（超前和滞后）数据
# * 移动（shifting）指的是沿着时间轴将数据迁移或后移

# %%
ts = pd.Series(np.random.randn(4),
              index = pd.date_range('1/1/2000',periods = 4,freq = 'M'))
print(ts)
print()
print(ts.shift(2))
print()
print(ts.shift(-2))
# Out:
# 2000-01-31    0.019353
# 2000-02-29   -0.222133
# 2000-03-31   -0.052624
# 2000-04-30   -0.466643
# Freq: M, dtype: float64
#
# 2000-01-31         NaN
# 2000-02-29         NaN
# 2000-03-31    0.019353
# 2000-04-30   -0.222133
# Freq: M, dtype: float64
#
# 2000-01-31   -0.052624
# 2000-02-29   -0.466643
# 2000-03-31         NaN
# 2000-04-30         NaN
# Freq: M, dtype: float64

# %%
Image(filename="py35_picture\Shifting.png")

# %%
print(ts.shift(2,freq = 'M'))
print()
print(ts.shift(3,freq = 'D'))
print()
print(ts.shift(1,freq = '3D'))
ts.shift(1,freq = '90T')
# Out:
# 2000-03-31    0.019353
# 2000-04-30   -0.222133
# 2000-05-31   -0.052624
# 2000-06-30   -0.466643
# Freq: M, dtype: float64
#
# 2000-02-03    0.019353
# 2000-03-03   -0.222133
# 2000-04-03   -0.052624
# 2000-05-03   -0.466643
# dtype: float64
#
# 2000-02-03    0.019353
# 2000-03-03   -0.222133
# 2000-04-03   -0.052624
# 2000-05-03   -0.466643
# dtype: float64
# 2000-01-31 01:30:00    0.019353
# 2000-02-29 01:30:00   -0.222133
# 2000-03-31 01:30:00   -0.052624
# 2000-04-30 01:30:00   -0.466643
# Freq: M, dtype: float64

# %% [markdown]
# * 通过偏移量对日期进行位移

# %%
from pandas.tseries.offsets import Day, MonthEnd

now = datetime(2011,11,17)
print(now)
print()
print(now + 3*Day())
print()
print(now + MonthEnd()) # 锚点偏移量（比如 MonthEnd），第一次增量会将原日期向前滚动到符合频率规则的下一个日期
print()
print(now + MonthEnd(2))
# Out:
# 2011-11-17 00:00:00
#
# 2011-11-20 00:00:00
#
# 2011-11-30 00:00:00
#
# 2011-12-31 00:00:00

# %%
offset = MonthEnd()
print(offset.rollforward(now)) # 锚点偏移量的两种方法
print()
print(offset.rollback(now))
# Out:
# 2011-11-30 00:00:00
#
# 2011-10-31 00:00:00

# %%
ts = pd.Series(np.random.randn(20),
              index = pd.date_range('1/15/2000',periods = 20, freq = '4d'))
ts.groupby(offset.rollforward).mean()
# Out:
# 2000-01-31   -0.007449
# 2000-02-29    0.460215
# 2000-03-31    0.185445
# dtype: float64

# %% [markdown]
# ## 四、时区处理

# %%
Image(filename="py35_picture\Time zone handling.png")

# %%
import pytz

print(pytz.common_timezones[-5:])
print()
tz = pytz.timezone('US/Eastern') # 从pytz中获取时区对象
tz
# Out:
# ['US/Eastern', 'US/Hawaii', 'US/Mountain', 'US/Pacific', 'UTC']
# <DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>

# %% [markdown]
# ### 1 本地化和转换

# %%
rng = pd.date_range('3/9/2012 9:30', periods = 6, freq = 'D')
ts = pd.Series(np.random.randn(len(rng)), index = rng) # pandas的时间序列是单纯的（naive）时区
print(ts.index.tz)
# Out:
# None

# %%
print(pd.date_range('3/9/2012 9:30',periods = 10, freq = 'D', tz = 'UTC')) # 加上时区集
print()
ts_utc = ts.tz_localize('UTC') # 从naive到本地转换
print(ts_utc.index)
print()
print(ts_utc.tz_convert('US/Eastern')) # 转到本地之后，就可以将其转换到别的时区了
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00', '2012-03-16 09:30:00+00:00',
#                '2012-03-17 09:30:00+00:00', '2012-03-18 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D')
#
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D')
#
# 2012-03-09 04:30:00-05:00   -0.056250
# 2012-03-10 04:30:00-05:00   -1.765975
# 2012-03-11 05:30:00-04:00   -1.077503
# 2012-03-12 05:30:00-04:00    0.663905
# 2012-03-13 05:30:00-04:00   -1.354857
# 2012-03-14 05:30:00-04:00    0.043128
# Freq: D, dtype: float64

# %%
ts_eastern = ts.tz_localize('US/Eastern') # 先本地化，再转换到UTC或柏林时间
print(ts_eastern.tz_convert('UTC'))
ts_eastern.tz_convert('Europe/Berlin')
# Out:
# 2012-03-09 14:30:00+00:00   -0.056250
# 2012-03-10 14:30:00+00:00   -1.765975
# 2012-03-11 13:30:00+00:00   -1.077503
# 2012-03-12 13:30:00+00:00    0.663905
# 2012-03-13 13:30:00+00:00   -1.354857
# 2012-03-14 13:30:00+00:00    0.043128
# Freq: D, dtype: float64
# 2012-03-09 15:30:00+01:00   -0.056250
# 2012-03-10 15:30:00+01:00   -1.765975
# 2012-03-11 14:30:00+01:00   -1.077503
# 2012-03-12 14:30:00+01:00    0.663905
# 2012-03-13 14:30:00+01:00   -1.354857
# 2012-03-14 14:30:00+01:00    0.043128
# Freq: D, dtype: float64

# %%
ts.index.tz_localize('Asia/Shanghai') # tz_localize 和 tz_convert 也是DatetimeIndex的实例方法
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+08:00', '2012-03-10 09:30:00+08:00',
#                '2012-03-11 09:30:00+08:00', '2012-03-12 09:30:00+08:00',
#                '2012-03-13 09:30:00+08:00', '2012-03-14 09:30:00+08:00'],
#               dtype='datetime64[ns, Asia/Shanghai]', freq='D')

# %% [markdown]
# ### 2 操作时区意识型Timestamp对象
# * Timestamp对象也能被从naive本地化为时区意识型（time zone-aware），并从一个时区转换到另一个时区

# %%
stamp = pd.Timestamp('2011-03-12 04:00')
stamp_utc = stamp.tz_localize('utc')
stamp_utc.tz_convert('US/Eastern')
# Out:
# Timestamp('2011-03-11 23:00:00-0500', tz='US/Eastern')

# %%
stamp_moscow = pd.Timestamp('2011-03-12 04:00', tz = 'Europe/Moscow')
stamp_moscow
# Out:
# Timestamp('2011-03-12 04:00:00+0300', tz='Europe/Moscow')

# %%
Image(filename="py35_picture\Time zone handling 2.png")

# %%
print(stamp_utc.value)
stamp_utc.tz_convert('US/Eastern').value
# Out:
# 1299902400000000000
# 1299902400000000000

# %%
# 使用pandas的Dateoffset对象运算时，会自动关注是否存在夏令时转变期
from pandas.tseries.offsets import Hour

# 夏令时转变前30分钟
stamp = pd.Timestamp('2012-03-12 01:30', tz = 'US/Eastern')
print(stamp)
print()
print(stamp + Hour())
# Out:
# 2012-03-12 01:30:00-04:00
#
# 2012-03-12 02:30:00-04:00

# %%
# 夏令时转变前90分钟
stamp = pd.Timestamp('2012-11-04 00:30', tz = 'US/Eastern')
print(stamp)
print()
print(stamp + 2 * Hour())
# Out:
# 2012-11-04 00:30:00-04:00
#
# 2012-11-04 01:30:00-05:00

# %% [markdown]
# ### 3 不同时区之间的运算
# * 如果两个时间序列的时区不同，在将它们合并到一起时，最终结果就会使UTC。

# %%
rng = pd.date_range('3/7/2012 9:30', periods = 10, freq = 'B')
ts = pd.Series(np.random.randn(len(rng)), index = rng)
print(ts)
print()
ts1 = ts[:7].tz_localize('Europe/London')
print(ts1)
ts2 = ts1[2:].tz_convert('Europe/Moscow')
ts2
# Out:
# 2012-03-07 09:30:00    1.135112
# 2012-03-08 09:30:00    1.669938
# 2012-03-09 09:30:00    0.093439
# 2012-03-12 09:30:00   -0.164918
# 2012-03-13 09:30:00   -0.930818
# 2012-03-14 09:30:00   -0.149066
# 2012-03-15 09:30:00    1.531612
# 2012-03-16 09:30:00   -1.826045
# 2012-03-19 09:30:00   -0.247548
# 2012-03-20 09:30:00   -0.485908
# Freq: B, dtype: float64
#
# 2012-03-07 09:30:00+00:00    1.135112
# 2012-03-08 09:30:00+00:00    1.669938
# 2012-03-09 09:30:00+00:00    0.093439
# 2012-03-12 09:30:00+00:00   -0.164918
# 2012-03-13 09:30:00+00:00   -0.930818
# 2012-03-14 09:30:00+00:00   -0.149066
# 2012-03-15 09:30:00+00:00    1.531612
# Freq: B, dtype: float64
# 2012-03-09 13:30:00+04:00    0.093439
# 2012-03-12 13:30:00+04:00   -0.164918
# 2012-03-13 13:30:00+04:00   -0.930818
# 2012-03-14 13:30:00+04:00   -0.149066
# 2012-03-15 13:30:00+04:00    1.531612
# Freq: B, dtype: float64

# %%
result = ts1 + ts2
result.index
# Out:
# DatetimeIndex(['2012-03-07 09:30:00+00:00', '2012-03-08 09:30:00+00:00',
#                '2012-03-09 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='B')
