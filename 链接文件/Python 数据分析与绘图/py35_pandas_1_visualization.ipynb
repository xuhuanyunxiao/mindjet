# %% [markdown]
# # pandas 绘图
# - pandas手册 visualization部分

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from IPython.display import Image

import matplotlib
matplotlib.style.use('ggplot')

# %matplotlib inline

# %% [markdown]
# ## 一、Basic Plotting: plot

# %%
df = pd.DataFrame()
print(dir(df.plot))
# Out:
# ['__bytes__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_constructor', '_dir_additions', '_dir_deletions', '_reset_cache', 'area', 'bar', 'barh', 'box', 'density', 'hexbin', 'hist', 'kde', 'line', 'pie', 'scatter']

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000',periods=1000))
ts = ts.cumsum()
ts[:5]
# Out:
# 2000-01-01    0.256371
# 2000-01-02    0.553032
# 2000-01-03    0.392978
# 2000-01-04    1.792194
# 2000-01-05    0.620844
# Freq: D, dtype: float64

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
df[:5]
# Out:
#                    A         B         C         D
# 2000-01-01 -0.089679 -0.448750 -1.026270 -1.035295
# 2000-01-02 -2.022157 -0.343653 -1.295769 -0.988092
# 2000-01-03 -2.264007  0.244507 -1.239825  1.543556
# 2000-01-04 -0.932298 -0.098705  0.187063  0.740013
# 2000-01-05 -2.099557  0.213415  1.030141  2.933909

# %%
df.plot()

# %% [markdown]
# ## 二、Other Plots
# > - ‘bar’ or ‘barh’ for bar plots
# > - ‘hist’ for histogram
# > - ‘box’ for boxplot
# > - ‘kde’ or 'density' for density plots
# > - ‘area’ for area plots
# > - ‘scatter’ for scatter plots
# > - ‘hexbin’ for hexagonal bin plots
# > - ‘pie’ for pie plots

# %% [markdown]
# ### 1 条形图

# %%
df.ix[5].plot(kind='bar'); plt.axhline(0, color='k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2[:5]
# Out:
#           a         b         c         d
# 0  0.404078  0.793302  0.412749  0.134798
# 1  0.534973  0.975364  0.875194  0.013992
# 2  0.630928  0.055675  0.925942  0.083006
# 3  0.991071  0.033116  0.251463  0.906807
# 4  0.153307  0.022422  0.383200  0.802537

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)

# %% [markdown]
# ### 2 直方图

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
df4[:5]
# Out:
#           a         b         c
# 0  2.238319 -0.388103 -0.053793
# 1  1.217399  0.716326 -2.173713
# 2  0.044832  0.014574 -0.852804
# 3  0.573594 -1.383731 -0.558541
# 4  1.146927 -0.041821 -0.434449

# %%
df4.plot.hist(alpha=0.5)

# %%
df4.plot.hist(stacked=True, bins=20)

# %%
df4['a'].plot.hist(orientation='horizontal', cumulative=True)

# %%
df['A'].diff().hist()

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024053CFFFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024054D80E80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024054DCD940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024054E087B8>]], dtype=object)

# %%
data = pd.Series(np.random.randn(1000))
data[:5]
# Out:
# 0   -0.320431
# 1   -0.910552
# 2    1.160920
# 3   -0.405652
# 4    0.625692
# dtype: float64

# %%
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024054E97128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000240551CA358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002405520AD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002405523DEF0>]], dtype=object)

# %% [markdown]
# ### 3 箱型图

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df[:5]
# Out:
#           A         B         C         D         E
# 0  0.063447  0.423332  0.457908  0.700750  0.633467
# 1  0.807189  0.456748  0.471324  0.897756  0.486595
# 2  0.344007  0.704606  0.483813  0.145670  0.588183
# 3  0.826825  0.760014  0.289414  0.645390  0.769001
# 4  0.654418  0.629104  0.584649  0.927664  0.444027

# %%
df.plot.box()

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')
df.plot.box(color=color, sym='r+')

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = pd.DataFrame(np.random.rand(10,5))
df[:5]
# Out:
#           0         1         2         3         4
# 0  0.983737  0.199013  0.715383  0.015521  0.501715
# 1  0.963039  0.874412  0.461182  0.385674  0.338954
# 2  0.050864  0.284852  0.123632  0.324950  0.508206
# 3  0.746344  0.698923  0.212735  0.343611  0.581344
# 4  0.177909  0.497254  0.562957  0.089302  0.567329

# %%
bp = df.boxplot()
# Out:
# D:\software\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':

# %%
df = pd.DataFrame(np.random.rand(10,2), columns=['Col1', 'Col2'] )
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
df[:5]
# Out:
#        Col1      Col2  X
# 0  0.894842  0.297428  A
# 1  0.485544  0.301350  A
# 2  0.872426  0.859694  A
# 3  0.456137  0.686230  A
# 4  0.976827  0.854286  A

# %%
bp = df.boxplot(by='X')

# %%
df = pd.DataFrame(np.random.rand(10,3), columns=['Col1', 'Col2', 'Col3'])
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
df['Y'] = pd.Series(['A','B','A','B','A','B','A','B','A','B'])
df[:5]
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.807907  0.617332  0.472099  A  A
# 1  0.233289  0.965258  0.561900  A  B
# 2  0.607049  0.767627  0.842969  A  A
# 3  0.772123  0.805257  0.547291  A  B
# 4  0.666137  0.895139  0.255298  A  A

# %%
bp = df.boxplot(column=['Col1','Col2'], by=['X','Y'])

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box['g'] = np.random.choice(['A', 'B'], size=50)
df_box.loc[df_box['g'] == 'B', 1] += 3
df_box[:5]
# Out:
#           0         1  g
# 0  0.471435 -1.190976  A
# 1  1.432707 -0.312652  A
# 2 -0.720589  3.887163  B
# 3  0.859588 -0.636524  A
# 4  0.015696  0.757315  B

# %%
bp = df_box.boxplot(by='g')

# %%
bp = df_box.groupby('g').boxplot()
# Out:
# D:\software\Anaconda3\lib\site-packages\pandas\tools\plotting.py:3082: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   rot=rot, grid=grid, **kwds)

# %% [markdown]
# ### 4 面积图

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df[:5]
# Out:
#           a         b         c         d
# 0  0.556895  0.084774  0.333002  0.728429
# 1  0.142435  0.552469  0.273043  0.974495
# 2  0.667787  0.255653  0.108311  0.776181
# 3  0.782478  0.761604  0.914403  0.658623
# 4  0.568368  0.201756  0.698296  0.952195

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %% [markdown]
# ### 5 散点图

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df[:5]
# Out:
#           a         b         c         d
# 0  0.712097  0.443909  0.031035  0.363240
# 1  0.730722  0.475567  0.344417  0.640880
# 2  0.126205  0.171465  0.737086  0.127029
# 3  0.369650  0.604334  0.103104  0.802374
# 4  0.945553  0.979039  0.881232  0.627682

# %%
df.plot.scatter(x='a', y='b')

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1')
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax)

# %%
df.plot.scatter(x='a', y='b', c='c', s=50)

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200)

# %% [markdown]
# ### 6 六边图：Hexagonal Bin Plot

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df[:5]
# Out:
#           a         b
# 0 -0.827198  0.914196
# 1 -0.931163  1.051704
# 2  0.627872  2.349277
# 3  0.088349  3.011981
# 4  0.749476  3.925354

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] = df['b'] + np.arange(1000)
df['z'] = np.random.uniform(0, 3, 1000)
df[:5]
# Out:
#           a         b         z
# 0 -0.793893  0.321153  0.051901
# 1  0.342250  2.618906  2.099913
# 2 -0.975807  3.918201  1.847558
# 3 -0.810847  1.594081  2.300502
# 4 -1.977759  4.461659  2.410117

# %%
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)

# %% [markdown]
# ### 7 饼图

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
series[:5]
# Out:
# a    2.632870
# b    0.125960
# c    2.970358
# d    2.438139
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(6, 6))

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'],columns=['x', 'y'])
df[:5]
# Out:
#           x         y
# a  1.723781  1.034762
# b  0.228865  2.799262
# c  0.217145  2.294694
# d  2.883440  2.384940

# %%
df.plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002405566BAC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024056E1C3C8>], dtype=object)

# %%
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
                 autopct='%.2f', fontsize=20, figsize=(6, 6))

# %%
series = pd.Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')
series[:5]
# Out:
# a    0.1
# b    0.1
# c    0.1
# d    0.1
# Name: series2, dtype: float64

# %%
series.plot.pie(figsize=(6, 6))

# %% [markdown]
# ## 三、Plotting with Missing Data

# %%
Image(filename="py35_picture\pandas_plot_missing.png")

# %% [markdown]
# ## 四、Plotting Tools

# %% [markdown]
# ### 1 矩阵绘图 Scatter Matrix Plot

# %%
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df[:5]
# Out:
#           a         b         c         d
# 0  0.016512 -1.458287 -0.308836 -1.621632
# 1 -0.975850  2.475554  0.056445 -1.079295
# 2 -1.245050 -1.074121  0.403729  1.064495
# 3  1.566674  0.219574 -0.124003  0.996877
# 4 -0.109752  0.580846  1.611185  1.687202

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024056A6D4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024056ABE6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024056B6C0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024056B8B3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024056F6F5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024056FADE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024057FCC668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024058008E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002405805B0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000240580A5400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000240580E0550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002405812A780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002405816B470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000240581B2F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000240581EF8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024058243160>]], dtype=object)

# %% [markdown]
# ### 2 Density Plot

# %%
ser = pd.Series(np.random.randn(1000))
ser[:5]
# Out:
# 0   -0.359332
# 1   -0.385736
# 2    0.548914
# 3    0.238238
# 4    1.475203
# dtype: float64

# %%
ser.plot.kde()

# %% [markdown]
# ### 3 Andrews Curves

# %%
from pandas.tools.plotting import andrews_curves
from sklearn.datasets import load_iris

d = load_iris()
data = pd.DataFrame(d.data,columns = d.feature_names)
data.columns.name = 'feature_names'
data[:5]
# Out:
# feature_names  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0                            5.1               3.5                1.4
# 1                            4.9               3.0                1.4
# 2                            4.7               3.2                1.3
# 3                            4.6               3.1                1.5
# 4                            5.0               3.6                1.4
#
# feature_names  petal width (cm)
# 0                           0.2
# 1                           0.2
# 2                           0.2
# 3                           0.2
# 4                           0.2

# %%
#andrews_curves(data, 'feature_names')

# %% [markdown]
# ### 4 Parallel Coordinates

# %%
from pandas.tools.plotting import parallel_coordinates

plt.figure()
#parallel_coordinates(data, 'sepal length')

# %%
from pandas.tools.plotting import lag_plot

plt.figure()
data = pd.Series(0.1 * np.random.rand(1000) +
     0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))
lag_plot(data)

# %% [markdown]
# ### 5 Autocorrelation Plot

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(0.7 * np.random.rand(1000) +
       0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))
autocorrelation_plot(data)

# %% [markdown]
# ### 6 Bootstrap Plot

# %%
from pandas.tools.plotting import bootstrap_plot

data = pd.Series(np.random.rand(1000))
bootstrap_plot(data, size=50, samples=500, color='grey')

# %% [markdown]
# ## 五、Plot Formatting

# %%
#plt.figure(); ts.plot(style='k--', label='Series');

# %% [markdown]
# ### 1 Controlling the Legend

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2000',periods=1000), columns=list('ABCD'))
df = df.cumsum()
print(df[:5])
df.plot(legend=False)
# Out:
#                    A         B         C         D
# 2000-01-01 -1.136183  0.515331 -1.665016  0.044897
# 2000-01-02 -1.025817 -0.459606  0.011666 -1.611901
# 2000-01-03 -1.899916 -1.766000  0.286560 -3.653845
# 2000-01-04 -1.100012 -2.150250  0.513180 -5.875060
# 2000-01-05 -0.962031 -3.038263  0.810086 -5.073168

# %% [markdown]
# ### 2 Scales

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000',periods=1000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True)

# %% [markdown]
# ### 3 Plotting on a Secondary Y-axis

# %%
df.A.plot()
df.B.plot(secondary_y=True, style='g')

# %%
plt.figure()
ax = df.plot(secondary_y=['A', 'B'])
ax.set_ylabel('CD scale')
ax.right_ax.set_ylabel('AB scale')

# %%
plt.figure()
df.plot(secondary_y=['A', 'B'], mark_right=False)

# %% [markdown]
# ### 4 Suppressing Tick Resolution Adjustment

# %%
plt.figure()
df.A.plot()

# %%
plt.figure()
df.A.plot(x_compat=True)

# %% [markdown]
# ### 5 Subplots

# %%
df.plot(subplots=True, figsize=(6, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000223A591D390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000223A59D4550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000223A5A1BDD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000223A5A57B38>], dtype=object)

# %% [markdown]
# ### 6 Using Layout and Targeting Multiple Axes

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(6, 6), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000223A5DD3C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223A5C2E160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223A5C75C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000223A5CB1978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223A5CFBBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223A59E2C18>]], dtype=object)

# %%
fig, axes = plt.subplots(4, 4, figsize=(6, 6));
plt.subplots_adjust(wspace=0.5, hspace=0.5);
target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]
target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]
df.plot(subplots=True, ax=target1, legend=False, sharex=False,sharey=False);

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
df['A'].plot(ax=axes[0,0]); axes[0,0].set_title('A');
df['B'].plot(ax=axes[0,1]); axes[0,1].set_title('B');
df['C'].plot(ax=axes[1,0]); axes[1,0].set_title('C');
df['D'].plot(ax=axes[1,1]); axes[1,1].set_title('D');

# %% [markdown]
# ### 7 Plotting With Error Bars

# %%
ix3 = pd.MultiIndex.from_arrays([['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'], [
         'foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar']], names=['letter', 'word'])
df3 = pd.DataFrame({'data1': [3, 2, 4, 3, 2, 4, 3, 2], 'data2': [6, 5, 7, 5,
        4, 5, 6, 5]}, index=ix3)
# Group by index labels and take the means and standard deviations for each group
gp3 = df3.groupby(level=('letter', 'word'))
means = gp3.mean()
errors = gp3.std()

print(means)
errors
# Out:
#              data1  data2
# letter word
# a      bar     3.5    6.0
#        foo     2.5    5.5
# b      bar     2.5    5.5
#        foo     3.0    4.5
#                 data1     data2
# letter word
# a      bar   0.707107  1.414214
#        foo   0.707107  0.707107
# b      bar   0.707107  0.707107
#        foo   1.414214  0.707107

# %%
fig, ax = plt.subplots()
means.plot.bar(yerr=errors, ax=ax)

# %% [markdown]
# ### 8 Plotting Tables

# %%
fig, ax = plt.subplots(1, 1)
df = pd.DataFrame(np.random.rand(5, 3), columns=['a', 'b', 'c'])
ax.get_xaxis().set_visible(False) # Hide Ticks
df.plot(table=True, ax=ax)

# %%
fig, ax = plt.subplots(1, 1)
ax.get_xaxis().set_visible(False) # Hide Ticks
df.plot(table=np.round(df.T, 2), ax=ax)

# %%
from pandas.tools.plotting import table

fig, ax = plt.subplots(1, 1)
table(ax, np.round(df.describe(), 2),loc='upper right', colWidths=[0.2, 0.2, 0.2])
df.plot(ax=ax, ylim=(0, 2), legend=None)

# %% [markdown]
# ### 9 Colormaps

# %%
df = pd.DataFrame(np.random.randn(1000, 10), index=pd.date_range('1/1/2000',periods=1000))
df = df.cumsum()
df[:5]
# Out:
#                    0         1         2         3         4         5  \
# 2000-01-01  0.703026  0.286081 -0.520050 -0.683758 -0.781948 -0.099877
# 2000-01-02  2.417535 -0.384919 -0.768633 -0.332983  0.154181  1.675273
# 2000-01-03  1.166846 -2.212669 -1.855001 -0.133809 -1.983373  1.285016
# 2000-01-04  0.478792 -2.634564 -2.268240  0.349583 -2.853437  1.519602
# 2000-01-05  0.381326 -3.139801 -1.528047  1.321794 -3.726536  1.713682
#
#                    6         7         8         9
# 2000-01-01  0.770018 -1.628521 -1.244127 -1.306978
# 2000-01-02  0.344779 -1.736015 -2.705753 -2.090721
# 2000-01-03 -1.841312 -2.186229 -2.737719 -1.651349
# 2000-01-04 -2.644620 -1.650243 -1.912412 -2.125943
# 2000-01-05 -3.696950 -0.617844 -2.228966 -1.640901

# %%
plt.figure()
df.plot(colormap='cubehelix')

# %%
from matplotlib import cm

plt.figure()
df.plot(colormap=cm.cubehelix)

# %%
dd = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)
dd = dd.cumsum()
dd[:5]
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.266973  0.629969  0.721821  0.258404  1.188548  0.342409  0.981313
# 1  1.289664  1.938448  0.940109  2.632934  1.329596  1.336446  2.238615
# 2  1.741734  3.143647  2.064620  3.667754  1.573931  1.410814  3.211274
# 3  1.868661  4.313834  2.285714  3.693488  1.901416  3.456478  3.716742
# 4  2.116710  4.606106  2.289127  4.605171  2.390864  3.506482  4.691259
#
#           7         8         9
# 0  0.607988  0.059688  2.948198
# 1  2.132988  0.903423  4.436517
# 2  2.889113  1.185361  5.111687
# 3  3.305300  1.315371  5.889939
# 4  3.800913  1.378365  6.664742

# %%
plt.figure()
dd.plot.bar(colormap='Greens')

# %% [markdown]
# ## 六、Plotting directly with matplotlib

# %%
price = pd.Series(np.random.randn(150).cumsum(),index=pd.date_range('2000-1-1', periods=150, freq='B'))
ma = price.rolling(20).mean()
mstd = price.rolling(20).std()

print(ma[-5:])
mstd[-5:]
# Out:
# 2000-07-24    3.876767
# 2000-07-25    3.863132
# 2000-07-26    4.018029
# 2000-07-27    4.210929
# 2000-07-28    4.309895
# Freq: B, dtype: float64
# 2000-07-24    0.843996
# 2000-07-25    0.814461
# 2000-07-26    0.933921
# 2000-07-27    1.140832
# 2000-07-28    1.272407
# Freq: B, dtype: float64

# %%
plt.figure()
plt.plot(price.index, price, 'k')
plt.plot(ma.index, ma, 'b')
plt.fill_between(mstd.index, ma-2*mstd, ma+2*mstd, color='b', alpha=0.2)
