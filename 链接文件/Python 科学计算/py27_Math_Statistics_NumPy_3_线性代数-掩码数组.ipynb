# %% [markdown]
# ## 三、线性代数

# %%
from IPython.display import Image
Image(filename="picture\linear algebra.png")

# %% [markdown]
# ### 1 各种乘积运算

# %% [markdown]
# ### 2 解线性方程组

# %% [markdown]
# ## 四、掩码数组

# %% [markdown]
# ## 五、文件存取

# %% [markdown]
# ## 六、内存映射数组
